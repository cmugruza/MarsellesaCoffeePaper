# %% [markdown]
# <a href="https://colab.research.google.com/github/cmugruza/MarsellesaCoffeePaper/blob/main/MarsellesaPaper_Figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This program/script is to reproduce the figure 2 in the article "Evaluation of the phenotypic performance of the coffee variety Marsellesa® over 1400 meters a.s.l as an alternative for coffee growing":
#
# The figure accounts on the Vegetative behavior of coffee varieties according to plant height (A: top left), number of branches (B: top right), branch length (C: center), and number of nodes per branch (D: down). Black: Block 1, Gray: Block 2, Light gray: Block 3.

# %% [markdown]
# Figure 2(A): Top left, number of branches.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()

y = [109.86,	107.37,	90.58,	99.05,	100.47,	88.66,	90.41,	100.17,	81.42] 
y_std_dev = [20.50,	9.07,	8.52,	11.45,	6.93,	10.93,	10.81,	12.505,	8.26]
x=np.arange(len(y))
plt.figure(figsize=(6, 6)) 
#define chart 
fig, ax = plt.subplots()

#create chart
ax.bar(x=x, #x-coordinates of bars
       height=y, #height of bars
       yerr=y_std_dev, #error bar width
       capsize=4) #length of error bar caps

barlist=plt.bar(np.arange(len(y)), y, edgecolor="black", linewidth=3)#, width = .5)
for i in [0,3,6]:
  barlist[i].set_color('#2F2F2F')
  barlist[i+1].set_color('#888888')
  barlist[i+2].set_color('#E0E0E0')
  
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = [ '1', '2', '3', '1', '2', '3', '1', '2', '3']#'Testing'
plt.xticks(x, labels)#, rotation='vertical')
ax.set_xticklabels(labels)

plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.xlabel('Red Caturra     Catimor      Marsellesa  ', fontsize=18)#\n\n''Variety', fontsize=18)  #previous 16
plt.ylabel('Plant height', fontsize=24)       
plt.savefig('Fig2a.png', dpi = 300, bbox_inches='tight', pad_inches=0.0)
#plt.errorbar(x, y, yerr=yerr, label='both limits (default)')
#plt.legend(loc='lower right')

# %% [markdown]
#  Figure 2(B): Top right, number of branches.

# %%
fig = plt.figure()

y = [27.13,	33.87,	29.33,	  29.07,	30.20,	31.13,    26.80,	31.67,	28.60	] 
y_std_dev = [7.61,	4.84,	3.48,	  4.29,	4.71,	2.76,   4.54,	5.78,	2.99]	
x=np.arange(len(y))

#define chart 
fig, ax = plt.subplots()

#create chart
ax.bar(x=x, #x-coordinates of bars
       height=y, #height of bars
       yerr=y_std_dev, #error bar width
       capsize=4) #length of error bar caps

barlist=plt.bar(np.arange(len(y)), y, linewidth=2, edgecolor='#000000')#, width = .5)
for i in [0,3,6]:
  barlist[i].set_color('#2F2F2F')
  barlist[i+1].set_color('#888888')
  barlist[i+2].set_color('#E0E0E0')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels = [ '1', '2', '3', '1', '2', '3', '1', '2', '3']#'Labeling blocks'
plt.xticks(x, labels)#, rotation='vertical')
ax.set_xticklabels(labels)
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.xlabel('Red Caturra     Catimor      Marsellesa  ', fontsize=18)#\n\n''Variety', fontsize=18)  #previous 16
plt.ylabel('Number of branches', fontsize=24)  #previous 16
plt.savefig('Fig2b.png', bbox_inches='tight', dpi = 300, pad_inches=0.0)

# %% [markdown]
# Figure 2(C): Center, branch length.

# %%
fig = plt.figure()

#y_up = [5.47	5.50	6.80	8.620689655	6.766666667	8.1	7.3	6.689655172	5.7]
#y_up_sd = [1.53	1.50	2.23	2.077323022	1.356550731	2.656806483	1.822275955	0.760800719	1.055363967]
#y_me = [8.03	8.07	8.57	10.55172414	10.13333333	12.9	10.8	10.27586207	9.733333333]
#y_me_sd = [1.96	1.76	2.31	1.638514286	1.833281086	2.218262756	1.689725544	1.306482511	1.460593487]
#y_lo = [9.60	9.67	9.33	12.62068966	12.6	15.1	14.13333333	14.27586207	13.16666667]
#y_lo_sd = [2.31	1.97	2.43	2.289943747	2.237609562	2.397556227	1.870521471	1.278854167	1.599209575]

y = [5.47,	8.03,	9.60,	5.50,	8.07,	9.67,	6.80,	8.57,	9.33,	8.620689655,	10.55172414,	12.62068966,	6.766666667,	10.13333333,	12.6,	8.1,	12.9,	15.1,	7.3,	10.8,	14.13333333,	6.689655172,	10.27586207,	14.27586207,	5.7,	9.733333333,	13.16666667]
y_std_dev = [1.53,	1.96,	2.31,	1.50,	1.76,	1.97,	2.23,	2.31,	2.43,	2.077323022,	1.638514286,	2.289943747,	1.356550731,	1.833281086,	2.237609562,	2.656806483,	2.218262756,	2.397556227,	1.822275955,	1.689725544,	1.870521471,	0.760800719,	1.306482511,	1.278854167,	1.055363967,	1.460593487,	1.599209575]

print(y)
x=np.arange(len(y))

#define chart 
plt.figure(figsize=(6, 12)) 
fig, ax = plt.subplots()

#create chart
ax.bar(x=x, #x-coordinates of bars
       height=y, #height of bars
       yerr=y_std_dev, #error bar width
       capsize=4) #length of error bar caps

barlist=plt.bar(np.arange(len(y)), y)
for i in [0,1,2,9,10,11,18,19,20]:
  barlist[i].set_color('#2F2F2F')
  barlist[i+3].set_color('#888888')
  barlist[i+6].set_color('#E0E0E0')

labels = [ 'upper branch', 'middle branch', 'lower branch', 'upper branch', 'middle branch', 'lower branch','upper branch', 'middle branch', 'lower branch',
          'upper branch', 'middle branch', 'lower branch', 'upper branch', 'middle branch', 'lower branch','upper branch', 'middle branch', 'lower branch',
          'upper branch', 'middle branch', 'lower branch', 'upper branch', 'middle branch', 'lower branch','upper branch', 'middle branch', 'lower branch']
plt.xticks(x, labels, rotation='vertical')#'Labeling upper/middle/lower branches'
ax.set_xticklabels(labels)
plt.rc('xtick', labelsize=18)#7) 
plt.rc('ytick', labelsize=18)#7) 
plt.xlabel('\n1     2      3     1     2      3      1     2     3 \n\n''Red Caturra     Catimor      Marsellesa  \n\n''Variety', fontsize=14)
plt.ylabel('Nodes per branch', fontsize=14)
plt.savefig('Fig2c.jpg', bbox_inches='tight', dpi = 300, pad_inches=0.0)
# Out:
# [5.47, 8.03, 9.6, 5.5, 8.07, 9.67, 6.8, 8.57, 9.33, 8.620689655, 10.55172414, 12.62068966, 6.766666667, 10.13333333, 12.6, 8.1, 12.9, 15.1, 7.3, 10.8, 14.13333333, 6.689655172, 10.27586207, 14.27586207, 5.7, 9.733333333, 13.16666667]

# %% [markdown]
# Figure 2(D): Down, number of nodes per branch.

# %%
fig = plt.figure()

y = [32.13,	41.57,	43.57,	34.00,	44.77,	46.63,	34.17,	39.80,	41.40,	40.31034483,	49.72413793,	55.51724138,	37.13333333,	45.23333333,	49.3,	32.16666667,	47.3,	54.83333333,	29.86666667,	39.2,	48.93333333,	30.17241379,	40.75862069,	48.82758621,	24.56666667,	34.9,	44.9]
y_std_dev = [8.30,	10.65,	12.10,	7.98,	8.03,	9.69,	9.42,	7.76,	8.70,	8.860439558,	8.361888678,	10.39787303,	6.532324576,	5.946214869,	7.502413405,	10.08270398,	8.251018746,	8.175165646,	5.360991502,	4.964702998,	7.969482021,	3.048055182,	3.158380829,	4.132354617,	3.578511859,	5.326252483,	6.407700109]

print(y)
x=np.arange(len(y))

#define chart 
fig, ax = plt.subplots()

#create chart
ax.bar(x=x, #x-coordinates of bars
       height=y, #height of bars
       yerr=y_std_dev, #error bar width
       capsize=4) #length of error bar caps

barlist=plt.bar(np.arange(len(y)), y)
for i in [0,1,2,9,10,11,18,19,20]:
  barlist[i].set_color('#2F2F2F')
  barlist[i+3].set_color('#888888')
  barlist[i+6].set_color('#E0E0E0')

labels = [ 'upper branch', 'middle branch', 'lower branch', 'upper branch', 'middle branch', 'lower branch','upper branch', 'middle branch', 'lower branch',
          'upper branch', 'middle branch', 'lower branch', 'upper branch', 'middle branch', 'lower branch','upper branch', 'middle branch', 'lower branch',
          'upper branch', 'middle branch', 'lower branch', 'upper branch', 'middle branch', 'lower branch','upper branch', 'middle branch', 'lower branch']
plt.xticks(x, labels, rotation='vertical')#'Labeling upper/middle/lower branches'
ax.set_xticklabels(labels)
plt.rc('xtick', labelsize=7) 
plt.rc('ytick', labelsize=7) 
plt.xlabel('\n1     2      3     1     2      3      1     2     3 \n\n''Red Caturra     Catimor      Marsellesa  \n\n''Variety', fontsize=14)
plt.ylabel('Branch length', fontsize=14)
plt.savefig('Fig2d.png', bbox_inches='tight', dpi = 300, pad_inches=0.0)
# Out:
# [32.13, 41.57, 43.57, 34.0, 44.77, 46.63, 34.17, 39.8, 41.4, 40.31034483, 49.72413793, 55.51724138, 37.13333333, 45.23333333, 49.3, 32.16666667, 47.3, 54.83333333, 29.86666667, 39.2, 48.93333333, 30.17241379, 40.75862069, 48.82758621, 24.56666667, 34.9, 44.9]
